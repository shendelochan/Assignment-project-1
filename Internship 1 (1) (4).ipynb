# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot

import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv('file1.csv')
data.head()
# Out:
#    Unnamed: 0                                           Agent_id status  \
# 0           0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1           1  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2           2  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3           3  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4           4  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
#
#       lost_reason                budget                                lease  \
# 0  Not responding                   NaN                                  NaN
# 1      Low budget                   NaN                                  NaN
# 2  Not responding  £121 - £180 Per Week  Full Year Course Stay 40 - 44 weeks
# 3      Low budget                   0-0                                    0
# 4       Junk lead                   NaN                                  NaN
#
#      movein                                             source  \
# ...

# %%
target= [(np.where(data['status']!=('WON'))),(np.where(data['status']!=('LOST')))]
target
# Out:
# [(array([    0,     1,     2, ..., 46605, 46606, 46607]),),
#  (array([   98,   111,   139, ..., 46570, 46586, 46592]),)]

# %%
target=np.where(((data['status']!='LOST')&(data['status']!='WON')))
print(target)
# Out:
# (array([  182,   613,   820,   896,  1419,  1546,  1580,  1635,  2003,
#         2268,  2469,  2567,  2611,  2737,  2777,  3015,  3245,  3446,
#         3755,  3940,  4007,  4770,  5002,  5222,  5963,  6020,  6089,
#         6167,  6184,  6422,  6430,  6431,  6627,  6761,  7085,  7100,
#         7594,  7695,  7963,  8147,  8322,  8805,  9151,  9318,  9561,
#         9825,  9832,  9948,  9951,  9988, 10077, 10377, 11044, 11320,
#        11386, 11457, 11486, 11521, 11591, 11871, 11931, 12220, 12236,
#        12566, 12580, 12682, 12788, 13098, 13266, 13391, 13489, 13545,
#        13574, 13837, 13958, 13996, 14012, 14561, 14839, 15096, 15150,
#        15209, 15221, 15311, 15363, 15403, 15966, 16056, 16467, 16514,
#        16547, 16638, 16665, 16749, 16757, 16768, 16814, 16849, 17112,
#        17445, 17490, 17588, 17797, 17808, 18287, 18634, 18759, 19101,
#        19319, 19389, 19453, 19761, 19849, 19885, 19901, 19934, 19936,
# ...

# %% [markdown]
# # fill 0 to all row where Nan value present

# %%
data.fillna(0)
# Out:
#        Unnamed: 0                                           Agent_id status  \
# 0               0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1               1  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2               2  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3               3  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4               4  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# ...           ...                                                ...    ...
# 46603       46603  2306878a9ad9b57686cd623dd285aaa9b25afdf627f651...   LOST
# 46604       46604  327ec29056cc47c24bf922f7dc0f78261dad5c726d7353...   LOST
# 46605       46605  1134c0a7d44fdae1afd7f1f64e2789496784095ca0a050...   LOST
# 46606       46606  8b8b029f1142f5cbc825aa6cbee01406c915c6b055db79...   LOST
# 46607       46607  1ea65ea38f2f574b3875ba895e4ff76b284b7725041612...   LOST
#
#             lost_reason                budget  \
# ...

# %%
#columns present in given dataset
data.columns
# Out:
# Index(['Unnamed: 0', 'Agent_id', 'status', 'lost_reason', 'budget', 'lease',
#        'movein', 'source', 'source_city', 'source_country', 'utm_source',
#        'utm_medium', 'des_city', 'des_country', 'room_type', 'lead_id'],
#       dtype='object')

# %%
#shape of dataset
data.shape
# Out:
# (46608, 16)

# %%
#type of given dataset
data.dtypes
# Out:
# Unnamed: 0         int64
# Agent_id          object
# status            object
# lost_reason       object
# budget            object
# lease             object
# movein            object
# source            object
# source_city       object
# source_country    object
# utm_source        object
# utm_medium        object
# des_city          object
# des_country       object
# room_type         object
# lead_id           object
# dtype: object

# %% [markdown]
# the above observation all dataset are in object data type.

# %% [markdown]
# # label Encoder

# %% [markdown]
# label encoder are used for object dataset converted into int data type.

# %%
from sklearn.preprocessing import LabelEncoder
LE= LabelEncoder()

# %%
data0= LE.fit_transform(data['Unnamed: 0'])
pd.Series(data0)
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 46603    46603
# 46604    46604
# 46605    46605
# 46606    46606
# 46607    46607
# Length: 46608, dtype: int64

# %%
data1 = LE.fit_transform(data['Agent_id'])
pd.Series(data1)
# Out:
# 0         12
# 1         20
# 2         87
# 3        110
# 4         12
#         ...
# 46603     15
# 46604     24
# 46605      5
# 46606     60
# 46607     13
# Length: 46608, dtype: int64

# %%
data2 = LE.fit_transform(data['status'])
pd.Series(data2)
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 46603    2
# 46604    2
# 46605    2
# 46606    2
# 46607    2
# Length: 46608, dtype: int64

# %%
data3 = LE.fit_transform(data['lost_reason'])
pd.Series(data3)
# Out:
# 0        21
# 1        16
# 2        21
# 3        16
# 4         8
#          ..
# 46603    15
# 46604    24
# 46605    15
# 46606    15
# 46607    15
# Length: 46608, dtype: int64

# %%
data4=LE.fit_transform(data['budget'])
pd.Series(data4)
# Out:
# 0        1857
# 1        1857
# 2        1758
# 3          10
# 4        1857
#          ...
# 46603    1840
# 46604    1840
# 46605    1816
# 46606     817
# 46607    1799
# Length: 46608, dtype: int64

# %%
data5=LE.fit_transform(data['lease'])
pd.Series(data5)
# Out:
# 0        311
# 1        311
# 2        266
# 3          2
# 4        311
#         ...
# 46603    263
# 46604    286
# 46605    266
# 46606     93
# 46607    266
# Length: 46608, dtype: int64

# %%
data6=LE.fit_transform(data['movein'])
pd.Series(data6)
# Out:
# 0        477
# 1        477
# 2        471
# 3        477
# 4        477
#         ...
# 46603     19
# 46604    438
# 46605    313
# 46606    456
# 46607     19
# Length: 46608, dtype: int64

# %%
data7=LE.fit_transform(data['source'])
pd.Series(data7)
# Out:
# 0        432
# 1        432
# 2        343
# 3        508
# 4        432
#         ...
# 46603    432
# 46604    432
# 46605    343
# 46606    579
# 46607    343
# Length: 46608, dtype: int64

# %%
data8=LE.fit_transform(data['source_city'])
pd.Series(data8)
# Out:
# 0        2626
# 1        2626
# 2        2630
# 3        2830
# 4        2626
#          ...
# 46603    2133
# 46604    2707
# 46605    2133
# 46606    3961
# 46607     354
# Length: 46608, dtype: int64

# %%
data9=LE.fit_transform(data['source_country'])
pd.Series(data9)
# Out:
# 0        110
# 1        110
# 2        167
# 3        167
# 4        110
#         ...
# 46603    101
# 46604    101
# 46605    101
# 46606    135
# 46607    167
# Length: 46608, dtype: int64

# %%
data10=LE.fit_transform(data['utm_source'])
pd.Series(data10)
# Out:
# 0         5
# 1         5
# 2        26
# 3        26
# 4         5
#          ..
# 46603    26
# 46604    26
# 46605    26
# 46606    19
# 46607    26
# Length: 46608, dtype: int64

# %%
data11=LE.fit_transform(data['utm_medium'])
pd.Series(data11)
# Out:
# 0        10
# 1        10
# 2         3
# 3         3
# 4        10
#          ..
# 46603     3
# 46604     3
# 46605     3
# 46606    50
# 46607     3
# Length: 46608, dtype: int64

# %%
data12=LE.fit_transform(data['des_city'])
pd.Series(data12)
# Out:
# 0        206
# 1         74
# 2         18
# 3         26
# 4        137
#         ...
# 46603     22
# 46604    135
# 46605    206
# 46606    206
# 46607     85
# Length: 46608, dtype: int64

# %%
data13=LE.fit_transform(data['des_country'])
pd.Series(data13)
# Out:
# 0         8
# 1         8
# 2         8
# 3         8
# 4        10
#          ..
# 46603     8
# 46604     8
# 46605     8
# 46606     8
# 46607     8
# Length: 46608, dtype: int64

# %%
data14=LE.fit_transform(data['room_type'])
pd.Series(data14)
# Out:
# 0        5
# 1        5
# 2        0
# 3        5
# 4        5
#         ..
# 46603    3
# 46604    3
# 46605    3
# 46606    5
# 46607    3
# Length: 46608, dtype: int64

# %%
data15=LE.fit_transform(data['lead_id'])
pd.Series(data15)
# Out:
# 0        24487
# 1        22098
# 2        17972
# 3         3592
# 4        30099
#          ...
# 46603     3303
# 46604     3905
# 46605    26007
# 46606     3905
# 46607    13998
# Length: 46608, dtype: int64

# %%
# concatenate method used for combine the all data set
xy=np.concatenate((data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12, data13, data14, data15 ))
xy
# Out:
# array([   12,    20,    87, ..., 26007,  3905, 13998])

# %% [markdown]
# # make dataframe

# %%
df=pd.DataFrame({'Unnamed: 0': data0,'Agent_id': data1, 'status': data2 , 'lost_reason':data3, 'budget':data4, 'lease':data5,
       'movein':data6, 'source':data7, 'source_city':data8, 'source_country':data9, 'utm_source':data10,
       'utm_medium':data11, 'des_city':data12, 'des_country':data13, 'room_type':data14, 'lead_id':data15})
df
# Out:
#        Unnamed: 0  Agent_id  status  lost_reason  budget  lease  movein  \
# 0               0        12       2           21    1857    311     477
# 1               1        20       2           16    1857    311     477
# 2               2        87       2           21    1758    266     471
# 3               3       110       2           16      10      2     477
# 4               4        12       2            8    1857    311     477
# ...           ...       ...     ...          ...     ...    ...     ...
# 46603       46603        15       2           15    1840    263      19
# 46604       46604        24       2           24    1840    286     438
# 46605       46605         5       2           15    1816    266     313
# 46606       46606        60       2           15     817     93     456
# 46607       46607        13       2           15    1799    266      19
#
#        source  source_city  source_country  utm_source  utm_medium  des_city  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Agent_id          int64
# status            int64
# lost_reason       int64
# budget            int64
# lease             int64
# movein            int64
# source            int64
# source_city       int64
# source_country    int64
# utm_source        int64
# utm_medium        int64
# des_city          int64
# des_country       int64
# room_type         int64
# lead_id           int64
# dtype: object

# %%
df.describe()
# Out:
#         Unnamed: 0      Agent_id        status   lost_reason        budget  \
# count  46608.00000  46608.000000  46608.000000  46608.000000  46608.000000
# mean   23303.50000     52.448056      2.202369     18.834342   1320.420078
# std    13454.71501     35.941921      0.749010      6.493600    652.909482
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%    11651.75000     22.000000      2.000000     15.000000    928.000000
# 50%    23303.50000     43.000000      2.000000     20.000000   1758.000000
# 75%    34955.25000     83.000000      2.000000     21.000000   1840.000000
# max    46607.00000    119.000000      5.000000     30.000000   1857.000000
#
#               lease        movein        source   source_city  source_country  \
# count  46608.000000  46608.000000  46608.000000  46608.000000    46608.000000
# mean     214.482235    304.466122    380.857342   2359.249013      131.246481
# ...

# %%
df.shape
# Out:
# (46608, 16)

# %%
df.describe()
# Out:
#         Unnamed: 0      Agent_id        status   lost_reason        budget  \
# count  46608.00000  46608.000000  46608.000000  46608.000000  46608.000000
# mean   23303.50000     52.448056      2.202369     18.834342   1320.420078
# std    13454.71501     35.941921      0.749010      6.493600    652.909482
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%    11651.75000     22.000000      2.000000     15.000000    928.000000
# 50%    23303.50000     43.000000      2.000000     20.000000   1758.000000
# 75%    34955.25000     83.000000      2.000000     21.000000   1840.000000
# max    46607.00000    119.000000      5.000000     30.000000   1857.000000
#
#               lease        movein        source   source_city  source_country  \
# count  46608.000000  46608.000000  46608.000000  46608.000000    46608.000000
# mean     214.482235    304.466122    380.857342   2359.249013      131.246481
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Agent_id          0
# status            0
# lost_reason       0
# budget            0
# lease             0
# movein            0
# source            0
# source_city       0
# source_country    0
# utm_source        0
# utm_medium        0
# des_city          0
# des_country       0
# room_type         0
# lead_id           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# the above observation, there area no duplicate value present in dataset.

# %%
df['status'].describe()
# Out:
# count    46608.000000
# mean         2.202369
# std          0.749010
# min          0.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max          5.000000
# Name: status, dtype: float64

# %%
df['status'].transform
# Out:
# <bound method Series.transform of 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 46603    2
# 46604    2
# 46605    2
# 46606    2
# 46607    2
# Name: status, Length: 46608, dtype: int64>

# %%
df.skew().sort_values()
# Out:
# des_country      -4.555663
# utm_source       -1.653129
# lease            -1.278943
# source_country   -1.032973
# budget           -0.997246
# source           -0.600339
# lost_reason      -0.420520
# room_type        -0.409940
# movein           -0.332164
# source_city      -0.304893
# des_city         -0.142722
# lead_id          -0.000200
# Unnamed: 0        0.000000
# Agent_id          0.472255
# utm_medium        1.759030
# status            3.411180
# dtype: float64

# %% [markdown]
# the above observation

# %%
plt.figure(figsize= (25,20))
plotnumber=1
for column in df[['Unnamed: 0','Agent_id','status', 'lost_reason', 'budget','lease','movein','source','source_city','source_country', 'utm_source','utm_medium','des_city','des_country','room_type','lead_id']]:
    if plotnumber<=16:
        
        ax= plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize= 20 )
    plotnumber+=1
plt.tight_layout()

# %%
df.drop(columns=['Unnamed: 0'],inplace=True, axis=1)

# %%
df.drop(columns= ['lead_id'],inplace=True,axis=1)

# %%
x= df.drop('status',axis=1)
y= df['status']

# %%
x.iloc[:,:,].boxplot(figsize=(20,20))
# Out:
# <Axes: >

# %%
x.shape
# Out:
# (46608, 13)

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # power transformer

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt= PowerTransformer()

x_new= pt.fit_transform(x)
x_new
# Out:
# array([[-1.341857  ,  0.30372113,  0.81077012, ...,  1.28333294,
#         -0.10311554,  0.89567966],
#        [-0.87055566, -0.48784611,  0.81077012, ..., -0.57248704,
#         -0.10311554,  0.89567966],
#        [ 0.99103823,  0.30372113,  0.66599352, ..., -1.5613076 ,
#         -0.10311554, -1.39510206],
#        ...,
#        [-1.97806958, -0.64002071,  0.75086419, ...,  1.28333294,
#         -0.10311554,  0.01749616],
#        [ 0.44021565, -0.64002071, -0.73749405, ...,  1.28333294,
#         -0.10311554,  0.89567966],
#        [-1.27317558, -0.64002071,  0.72600373, ..., -0.40098542,
#         -0.10311554,  0.01749616]])

# %%
x= pd.DataFrame(x_new,columns=x.columns)
x
# Out:
#        Agent_id  lost_reason    budget     lease    movein    source  \
# 0     -1.341857     0.303721  0.810770  0.945869  1.057184  0.400265
# 1     -0.870556    -0.487846  0.810770  0.945869  1.057184  0.400265
# 2      0.991038     0.303721  0.665994  0.491447  1.022216 -0.392570
# 3      1.371078    -0.487846 -2.035463 -2.019462  1.057184  1.124229
# 4     -1.341857    -1.634305  0.810770  0.945869  1.057184  0.400265
# ...         ...          ...       ...       ...       ...       ...
# 46603 -1.145693    -0.640021  0.785940  0.461306 -1.853248  0.400265
# 46604 -0.682571     0.800561  0.785940  0.692891  0.829094  0.400265
# 46605 -1.978070    -0.640021  0.750864  0.491447  0.083428 -0.392570
# 46606  0.440216    -0.640021 -0.737494 -1.203304  0.934603  1.835504
# 46607 -1.273176    -0.640021  0.726004  0.491447 -1.853248 -0.392570
#
#        source_city  source_country  utm_source  utm_medium  des_city  \
# ...

# %%
x.iloc[:,:,].boxplot(figsize=(20,20))
# Out:
# <Axes: >

# %% [markdown]
# # z_score

# %%
from scipy.stats import zscore

z= zscore(x)

z1= np.abs(zscore(x))

z1
# Out:
#        Agent_id  lost_reason    budget     lease    movein    source  \
# 0      1.341857     0.303721  0.810770  0.945869  1.057184  0.400265
# 1      0.870556     0.487846  0.810770  0.945869  1.057184  0.400265
# 2      0.991038     0.303721  0.665994  0.491447  1.022216  0.392570
# 3      1.371078     0.487846  2.035463  2.019462  1.057184  1.124229
# 4      1.341857     1.634305  0.810770  0.945869  1.057184  0.400265
# ...         ...          ...       ...       ...       ...       ...
# 46603  1.145693     0.640021  0.785940  0.461306  1.853248  0.400265
# 46604  0.682571     0.800561  0.785940  0.692891  0.829094  0.400265
# 46605  1.978070     0.640021  0.750864  0.491447  0.083428  0.392570
# 46606  0.440216     0.640021  0.737494  1.203304  0.934603  1.835504
# 46607  1.273176     0.640021  0.726004  0.491447  1.853248  0.392570
#
#        source_city  source_country  utm_source  utm_medium  des_city  \
# ...

# %%
df_new= x[(z1<3).all(axis=1)]
df_new
# Out:
#        Agent_id  lost_reason    budget     lease    movein    source  \
# 0     -1.341857     0.303721  0.810770  0.945869  1.057184  0.400265
# 1     -0.870556    -0.487846  0.810770  0.945869  1.057184  0.400265
# 2      0.991038     0.303721  0.665994  0.491447  1.022216 -0.392570
# 3      1.371078    -0.487846 -2.035463 -2.019462  1.057184  1.124229
# 4     -1.341857    -1.634305  0.810770  0.945869  1.057184  0.400265
# ...         ...          ...       ...       ...       ...       ...
# 46603 -1.145693    -0.640021  0.785940  0.461306 -1.853248  0.400265
# 46604 -0.682571     0.800561  0.785940  0.692891  0.829094  0.400265
# 46605 -1.978070    -0.640021  0.750864  0.491447  0.083428 -0.392570
# 46606  0.440216    -0.640021 -0.737494 -1.203304  0.934603  1.835504
# 46607 -1.273176    -0.640021  0.726004  0.491447 -1.853248 -0.392570
#
#        source_city  source_country  utm_source  utm_medium  des_city  \
# ...

# %%
df_new.iloc[:,:,].boxplot(figsize=(20,20))
# Out:
# <Axes: >

# %%
x.skew().sort_values()
# Out:
# lease            -1.247543
# budget           -1.040843
# source_country   -0.539771
# utm_source       -0.462428
# room_type        -0.430429
# movein           -0.405564
# des_city         -0.335661
# source_city      -0.329686
# Agent_id         -0.087042
# lost_reason      -0.064779
# utm_medium       -0.061093
# source            0.039499
# des_country       1.364256
# dtype: float64

# %%
df.corr()['status'].sort_values()
# Out:
# movein           -0.054850
# budget           -0.031074
# des_city         -0.019450
# lease            -0.006737
# utm_source       -0.002484
# room_type         0.007209
# source_city       0.010907
# des_country       0.012345
# utm_medium        0.023036
# source            0.027398
# Agent_id          0.033199
# source_country    0.036101
# lost_reason       0.464584
# status            1.000000
# Name: status, dtype: float64

# %%
plt.figure(figsize= (25,20))
plotnumber=1
for column in df[['Agent_id','status', 'lost_reason', 'budget','lease','movein','source','source_city','source_country', 'utm_source','utm_medium','des_city','des_country','room_type']]:
    if plotnumber<=16:
        
        ax= plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize= 20 )
    plotnumber+=1
plt.tight_layout()

# %%
df.drop(columns=['lease','movein','budget','des_city','utm_source'],inplace=True, axis=1)

# %% [markdown]
# # target variable analysis

# %%
target= df['status']
sns.histplot(target)

print(df['status'].value_counts())
# Out:
# 2    43244
# 5     3073
# 3      254
# 0       28
# 4        8
# 1        1
# Name: status, dtype: int64

# %%
data['status']= LE.fit_transform(data['status'])

# %%
df['status'].value_counts()
# Out:
# 2    43244
# 5     3073
# 3      254
# 0       28
# 4        8
# 1        1
# Name: status, dtype: int64

# %%
LE.inverse_transform([0,1,2,3,4,5])
# Out:
# array(['CONTACTED', 'IMPORTANT', 'LOST', 'OPPORTUNITY', 'PROCESSING',
#        'WON'], dtype=object)

# %%
x
# Out:
#        Agent_id  lost_reason    budget     lease    movein    source  \
# 0     -1.341857     0.303721  0.810770  0.945869  1.057184  0.400265
# 1     -0.870556    -0.487846  0.810770  0.945869  1.057184  0.400265
# 2      0.991038     0.303721  0.665994  0.491447  1.022216 -0.392570
# 3      1.371078    -0.487846 -2.035463 -2.019462  1.057184  1.124229
# 4     -1.341857    -1.634305  0.810770  0.945869  1.057184  0.400265
# ...         ...          ...       ...       ...       ...       ...
# 46603 -1.145693    -0.640021  0.785940  0.461306 -1.853248  0.400265
# 46604 -0.682571     0.800561  0.785940  0.692891  0.829094  0.400265
# 46605 -1.978070    -0.640021  0.750864  0.491447  0.083428 -0.392570
# 46606  0.440216    -0.640021 -0.737494 -1.203304  0.934603  1.835504
# 46607 -1.273176    -0.640021  0.726004  0.491447 -1.853248 -0.392570
#
#        source_city  source_country  utm_source  utm_medium  des_city  \
# ...

# %% [markdown]
# # model apply

# %%
y
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 46603    2
# 46604    2
# 46605    2
# 46606    2
# 46607    2
# Name: status, Length: 46608, dtype: int64

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import warnings
warnings. filterwarnings('ignore')
# %matplotlib inline

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,random_state= 41)

# %%
def metric_score(clf, x_train, x_test,y_train, y_test, train=True):
    if train:
        y_pred= clf.predict(x_train)
        
        print('\n=======Train Result======')
        
        print(f'Accuracy Score: {accuracy_score(y_train, y_pred)* 100:.2f}%')
        
    elif train== False:
        pred= clf.predict(x_test)
        
        print('\n=======Test Result======')
        print(f'Accuracy Score:{accuracy_score(y_test, pred)* 100:.2f}%')
        
        print ('\n \n Test Classification Report \n', classification_report(y_test, pred,digits=2 ))

# %% [markdown]
# # random forest classifier

# %%
random_clf=  RandomForestClassifier()
random_clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
metric_score(random_clf, x_train, x_test, y_train, y_test, train= True)
metric_score(random_clf, x_train, x_test, y_train, y_test, train= False)
# Out:
# =======Train Result======
# Accuracy Score: 100.00%
#
# =======Test Result======
# Accuracy Score:99.47%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            2       1.00      1.00      1.00     10805
#            3       0.73      0.17      0.28        64
#            4       0.00      0.00      0.00         1
#            5       0.93      0.99      0.96       778
#
#     accuracy                           0.99     11652
#    macro avg       0.53      0.43      0.45     11652
# weighted avg       0.99      0.99      0.99     11652

# %% [markdown]
# # logistic classification

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression

# %%
lr= LogisticRegression()

lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
metric_score(lr, x_train, x_test, y_train, y_test, train= True)
metric_score(lr, x_train, x_test, y_train, y_test, train= False)
# Out:
# =======Train Result======
# Accuracy Score: 99.36%
#
# =======Test Result======
# Accuracy Score:99.41%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            2       1.00      1.00      1.00     10805
#            3       0.00      0.00      0.00        64
#            4       0.00      0.00      0.00         1
#            5       0.92      1.00      0.96       778
#
#     accuracy                           0.99     11652
#    macro avg       0.38      0.40      0.39     11652
# weighted avg       0.99      0.99      0.99     11652
